# %% [markdown]
# # Exercício 3
#
# ![image.png](attachment:image.png)

# %%
from typing import Callable
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Alínea 1

# %%
# Obter os dados
piano = np.loadtxt("03-piano.txt", float)
trompete = np.loadtxt("03-trumpet.txt", float)

N = len(piano)
print(N)

# Representação Gráfica
plt.plot(piano)
plt.title("Piano")
plt.show()

plt.plot(trompete)
plt.title("Trompete")
plt.show()
# Out:
# 100000

# %%
kk = np.arange(0, int(N/2))

# Coeficientes do Piano
cp = np.fft.fft(piano)[z]

plt.plot(kk, np.abs(cp))
plt.title("Coeficientes do Piano")
plt.grid()
plt.show()

# %%
# Coeficientes do Trompete
ct = np.fft.fft(trompete)[:int(N/2)]

plt.plot(kk, np.abs(ct))
plt.title("Coeficientes do Trompete")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       1 # Coeficientes do Trompete
#       2 ct = np.fft.fft(trompete)[:int(N/2)]
# ----> 4 plt.plot(kk, np.abs(ct))
#       5 plt.title("Coeficientes do Trompete")
#       6 plt.grid()
#
# File c:\Users\Gui\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2748, in plot(scalex, scaley, data, *args, **kwargs)
#    2746 @_copy_docstring_and_deprecators(Axes.plot)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2748     return gca().plot(
#    2749         *args, scalex=scalex, scaley=scaley,
#    2750         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\Gui\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1668, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1425 """
# ...

# %% [markdown]
# Nos dois casos vemos que os instrumentos têm harmónicos, isto é, picos da frequência em múltiplos interios de uma frequência fundamental, que deverá ser a frequência que o músico está a tocar!

# %% [markdown]
# ## Alínea 2

# %%
# Determinar o primeiro pico de k nos dois casos
kmaxpiano = np.argmax(cp)
kmaxtrompete = np.argmax(ct[:2000])

kmax = (kmaxpiano + kmaxtrompete) // 2

print(kmax)
# Out:
# 1186

# %% [markdown]
# A frequência associada é então:
#
# $$
# f = 1186 \times \frac{44100}{100000} = 523\text{ Hz}
# $$
#
# Ou seja, os instrumentos estão a tocar uma oitava acima do Dó médio!
