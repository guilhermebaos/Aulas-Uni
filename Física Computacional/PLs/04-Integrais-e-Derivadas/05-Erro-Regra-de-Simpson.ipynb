# %% [markdown]
# # Exercício 5
#
# ![image.png](attachment:image.png)
#
# Resolvido [aqui](https://www.notion.so/guilhermebaos/4-Regra-de-Simpson-dcd706b5ae7b4e65998440a9844c5f1f?pvs=4#b80b2f9e7465401796bf4e11ca41b6dd).
