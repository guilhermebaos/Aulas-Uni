# %% [markdown]
# # Exercício 3
#
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pylab as plt

# %%
# Obter os dados
dados = np.loadtxt("03-stm.txt", float)

# Mostrar a imagem
plt.imshow(dados, origin="lower")
plt.hot()
plt.show()
